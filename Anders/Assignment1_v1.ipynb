# %%
# http://www.cse.chalmers.se/~richajo/dat450/assignments/assignment1.html

# %% [markdown]
# ## Warmup: computing word frequencies

# %%
from collections import Counter,defaultdict
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
ENCODING = ['ISO-8859-1']#,'UTF-8']
file_names = ['europarl.txt', 'wikipedia.txt','books.txt']

# %%
for file_name in file_names:
    freqs = Counter()
    for encoding in ENCODING:
        with open('a1_data/'+file_name, encoding=encoding) as f:
            for line in f:
                tokens = line.lower().split()
                for token in tokens:
                    freqs[token] += 1
        print(f"Most frequent words in: {file_name} and encoding {encoding}")
        print(10*"=")
        for word, freq in freqs.most_common(10):
            print(word, freq)
# Out:
# Most frequent words in: europarl.txt and encoding ISO-8859-1
# ==========
# the 3003924
# , 2115604
# . 1536501
# of 1422251
# to 1341423
# and 1158191
# in 945124
# that 732141
# a 673990
# is 671961
# Most frequent words in: wikipedia.txt and encoding ISO-8859-1
# ==========
# the 3158463
# , 2566261
# . 1956600
# of 1534698
# and 1260516
# in 1205759
# a 958283
# to 926287
# - 548244
# is 522101
# Most frequent words in: books.txt and encoding ISO-8859-1
# ==========
# the 2425678
# , 2064433
# . 1958494
# and 1367843
# of 1321821
# to 1159024
# a 1103939
# is 792900
# in 739009
# i 704436

# %%
freqs.most_common(10)
# Out:
# [('the', 2425678),
#  (',', 2064433),
#  ('.', 1958494),
#  ('and', 1367843),
#  ('of', 1321821),
#  ('to', 1159024),
#  ('a', 1103939),
#  ('is', 792900),
#  ('in', 739009),
#  ('i', 704436)]

# %% [markdown]
# ### dictionary-within-dictionary
# find the words that most frequently follow the word red.

# %%
freqs = defaultdict(Counter)
for file_name in file_names:
    freqs = defaultdict(Counter)
    with open('a1_data/'+file_name, encoding='ISO-8859-1') as f:
        for line in f:
            tokens = line.lower().split()
            for t1, t2 in zip(tokens, tokens[1:]):
                freqs[t1][t2] += 1
    print(f"10 Most common words after 'red' in: {file_name} is:")
    words = freqs["red"].most_common(10)
    
    w = "Words"
    fre = "Frequency"
    print(f"{w} {fre:>{30}}")
    for word, freq in words:
        print(f"{word:{10}} {freq:>{20}}")
    print("\n")
# Out:
# 10 Most common words after 'red' in: europarl.txt is:
# Words                      Frequency
# tape                        856
# cross                       213
# card                         54
# lines                        37
# and                          26
# army                         26
# light                        25
# line                         23
# ,                            22
# .                            18
#
#
# 10 Most common words after 'red' in: wikipedia.txt is:
# Words                      Frequency
# ,                           532
# sox                         495
# and                         467
# -                           454
# army                        404
# cross                       278
# .                           213
# wings                       208
# sea                         177
# river                       166
#
#
# 10 Most common words after 'red' in: books.txt is:
# Words                      Frequency
# sox                         198
# herrings                    175
# ,                           132
# army                        126
# and                         104
# riding                       83
# wine                         75
# october                      69
# cross                        65
# "                            65

# %% [markdown]
# ## Investigating the word frequency distribution

# %%
def plot_most_frequent_words(file_name,n):
    freqs = Counter()
    with open('a1_data/'+file_name, encoding='ISO-8859-1') as f:
        for line in f:
            tokens = line.lower().split()
            for token in tokens:
                freqs[token] += 1

    #Plot
    Word = []
    Freq = []
    for word, freq in freqs.most_common(n):
        Word.append(word)
        Freq.append(freq)
    plt.subplots(figsize=(25,4));
    plt.bar(Word,Freq);
    plt.xticks(rotation=90);

# %%
plot_most_frequent_words('europarl.txt',50)

# %%
plot_most_frequent_words('wikipedia.txt',50)

# %%
plot_most_frequent_words('books.txt',50)

# %% [markdown]
#  #### Zipf's law
#
#  - Disussion !!!
#  https://www.youtube.com/watch?v=4dofBw9r0P4

# %% [markdown]
# ## Comparing corpora

# %%
# Vad är typiska ord för varje bok. Tex gör enräkna bort de som ingår i varje text

# %% [markdown]
# ## Side show: preprocessing text for machine learning
# TODO:
# 1. Enode the data. Enode one word to one integer **Done**
# 2. Make batching. convert a small set of texts into a matrix where each row represents one text (e.g. a document or sentence). **Make use of padding if necessary**

# %% [markdown]
# ### 1. Encoding

# %%
#### TODO ####
"""
1. Läs in raw text ord för ord och gör om allt till lower -Done
2. Skapa en vocab baserat på vanligaste ordern
3. Skapa avkodning
4. Skapa avkodad paddad text
"""


# Öppna texten som rader. 
# Koda av 
# Padda rader med -1
# Dela upp i batches

# %%
with open('a1_data/europarl.txt', encoding='ISO-8859-1') as f:
    # 1. Read in lines and set to lower
    raw_text = f.readlines()  # List of complete texyt

# Make all characters lower
raw_text  = [raw_text[i].lower() for i in range(len(raw_text))] 
    
# Split list into list with sublists (lower)
raw_text_splitted = [raw_text[i].split() for i in range(len(raw_text))]

# %%
# 2. Get vocabulary of most frequent words
max_voc_size=1000
freqs = Counter()
for line in raw_text:
    #tokens = line.lower().split()
    tokens = line.split()
    for token in tokens: 
        freqs[token] += 1
vocabulary_characters =  [word[0] for word in freqs.most_common(max_voc_size)]
vocabulary = dict(enumerate(vocabulary_characters,start=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-3508cb7f29ad> in <module>
#       2 max_voc_size=1000
#       3 freqs = Counter()
# ----> 4 for line in raw_text:
#       5     #tokens = line.lower().split()
#       6     tokens = line.split()
#
# NameError: name 'raw_text' is not defined

# %%
# Create decoder
flat_list = []
for sublist in raw_text_splitted:
    for item in sublist:
        flat_list.append(item)
decode = dict(enumerate(set(flat_list)))
decode.update({-1:""}) # Add -1 encoded to -1 in order
encode = {char: ind for ind,char in dec.items()}

# %%
# 4 Create decoded text with padding
max_sentence_length = len(max(raw_text_splitted, key=len)) # Get max length of sentence (text is a list of lists: Function get max len of lists in a list)
encoded_text = np.ones([len(raw_text_splitted), max_sentence_length])*-1 #Initiate matrix for decoded ords (padded with -1)

# %%
for row in range(len(raw_text_splitted)):
    for word in range(len(raw_text_splitted[row])):
        decoded_text[row,word] = decoded_text

# %%
class Vocab():
    def __init__(self,f):
        self.f = f
        
    def build_vocab(self):
        return self.f.readlines()

# %% [markdown]
# ### 2 Batch

# %%
len(encoded_text)
# Out:
# 17

# %% [markdown]
# ## Trying out an NLP toolkit

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### Processing a text

# %%
example = 'Apple bought two companies this year and no one knew, Mark Gurman at 9to5Mac reports.'

# %%
result = nlp(example)

# %%
for r in result: 
    #print(r.text)
    break 
    print(dir(r))

# %%
#dir(r)

# %% [markdown]
# ### Visualizing the results

# %%
from spacy import displacy
# Skriv dep för ordklass ent för ??
displacy.render(result, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2d11c0bb019486cb4fea2bc2c641754-0" class="displacy" width="18600" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">days</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">read</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">once</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">started</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">put</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">down .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">mr.magnus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">leads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">us</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">various</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">exercises</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">us</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">too</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADV</tspan>

# %% [markdown]
# ### Accessing the results in your code
# - token.text, the text of the token: for instance, the fourth of the tokens in the previous example is "companies"
# - token.pos_, the part-of-speech tag: "NOUN" for the same token **ORDKLASS**
# - token.lemma_, the uninflected base form or dictionary form: "company" **DEN OBÖJDA BASFORMEN**
# - token.head, a reference to the parent token in the dependency graph: "bought" **REF till överordnad token. Tex. vad gjorde apple, -vad-> Köpte. Detta -vad-> Året**
# - token.dep_, the label on the edge in the dependency tree between the head and this token: "dobj" (direct object)

# %%
for token in result:
    print(token.text, token.pos_, token.lemma_, token.head, token.dep_)
# Out:
# it PRON it took nsubj
# took VERB take took ROOT
# me PRON I took dobj
# two NUM two days nummod
# days NOUN day took npadvmod
# to PART to read aux
# read VERB read took xcomp
# this DET this book det
# book NOUN book read dobj
# because SCONJ because put mark
# once SCONJ once started mark
# i PRON I started nsubj
# started VERB start put advcl
# i PRON I put nsubj
# could AUX could put aux
# n't PART n't put neg
# put VERB put took advcl
# it PRON it put dobj
# down ADP down put prt
# . PUNCT . took punct
# mr.magnus PRON mr.magnus leads nsubj
# leads VERB lead leads ROOT
# us PRON we leads dobj
# through ADP through leads prep
# various ADJ various exercises amod
# exercises NOUN exercise through pobj
# to PART to show aux
# show VERB show leads advcl
# us PRON we show dobj
# how ADV how have advmod
# we PRON we have nsubj
# too ADV too we advmod
# can AUX can have aux
# have VERB have show ccomp
# an DET an projection det
# astral ADJ astral projection amod
# projection NOUN projection have dobj
# . PUNCT . leads punct
# the DET the exercises det
# exercises NOUN exercise are nsubj
# are AUX be are ROOT
# fun ADJ fun are acomp
# and CCONJ and fun cc
# interesting ADJ interesting fun conj
# . PUNCT . are punct
# he PRON he adds nsubj
# also ADV also adds advmod
# adds VERB add adds ROOT
# entries NOUN entry adds dobj
# from ADP from adds prep
# his PRON his journal poss
# journal NOUN journal from pobj
# that DET that makes nsubj
# makes VERB make adds ccomp
# the DET the reader det
# reader NOUN reader feel nsubj
# feel VERB feel makes ccomp
# that SCONJ that achieve mark
# they PRON they achieve nsubj
# too ADV too achieve advmod
# can AUX can achieve aux
# achieve VERB achieve feel ccomp
# the DET the ability det
# ability NOUN ability achieve dobj
# to PART to enter aux
# enter VERB enter ability acl
# the DET the realm det
# astral ADJ astral realm compound
# realm NOUN realm enter dobj
# . PUNCT . adds punct
# this DET this book det
# book NOUN book is nsubj
# is AUX be is ROOT
# easy ADJ easy is acomp
# to PART to read aux
# read VERB read easy xcomp
# unlike ADP unlike read prep
# many ADJ many books amod
# other ADJ other books amod
# books NOUN book unlike pobj
# on ADP on read prep
# the DET the subject det
# subject NOUN subject on pobj
# which DET which make nsubj
# make VERB make subject relcl
# the DET the reader det
# reader NOUN reader feel nsubj
# feel AUX feel bogged auxpass
# bogged VERB bogge make ccomp
# down ADP down bogged prt
# with ADP with bogged prep
# specificities NOUN specificity with pobj
# which DET which become nsubj
# soon ADV soon become advmod
# become VERB become specificities relcl
# boring ADJ boring become acomp
# . PUNCT . is punct
# a DET a book det
# beautifully ADV beautifully written advmod
# written VERB write book amod
# , PUNCT , written punct
# enthusiastic ADJ enthusiastic book amod
# book NOUN book book ROOT
# about ADP about book prep
# a DET a subject det
# subject NOUN subject about pobj
# that DET that surrounded nsubjpass
# is AUX be surrounded auxpass
# surrounded VERB surround subject relcl
# in ADP in surrounded prep
# mystery NOUN mystery
#  compound
#
#  SPACE
#  in pobj

# %% [markdown]
# ###### Similarly, we can process the named entities:

# %%
for entity in result.ents:
    print(entity.text ,entity.label_)
# Out:
# two days DATE

# %% [markdown]
# ## Additional questions
# 1. What are the most common nouns in Books

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# Load in text data
ENCODING = ['ISO-8859-1']
file_names = ['europarl.txt', 'wikipedia.txt','books.txt']

with open('a1_data/'+file_names[2], encoding=ENCODING[0]) as f:
    text = f.read()

# %%
print(text[:200])
# Out:
# it took me two days to read this book because once i started i could n't put it down . mr.magnus leads us through various exercises to show us how we too can have an astral projection . the exercises

# %%
len(text)
# Out:
# 256441196

# %%
text = str(text)

# %%
result = nlp(text)
#result[:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-304-da2b1e68b057> in <module>
# ----> 1 result = nlp(text)
#       2 #result[:10]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     996         DOCS: https://spacy.io/api/language#call
#     997         """
# --> 998         doc = self.make_doc(text)
#     999         if component_cfg is None:
#    1000             component_cfg = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/language.py in make_doc(self, text)
#    1076         """
#    1077         if len(text) > self.max_length:
# -> 1078             raise ValueError(
#    1079                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1080             )
#
# ValueError: [E088] Text of length 256441196 exceeds maximum of 1000000. The parser and NER models require roughly 1GB of temporary memory per 100,000 characters in the input. This means long texts may cause memory allocation errors. If you're not using the parser or NER, it's probably safe to increase the `nlp.max_length` limit. The limit is in number of characters, so you can check whether your inputs are too long by checking `len(text)`.

# %%
freqs = Counter()
for token in result:
    #print(token.pos_)
    if token.pos_ == "NOUN": 
        #print(token.text)
        freqs[token.text] += 1
freqs.most_common(10)
# Out:
# [('book', 8),
#  ('exercises', 2),
#  ('reader', 2),
#  ('subject', 2),
#  ('days', 1),
#  ('projection', 1),
#  ('entries', 1),
#  ('journal', 1),
#  ('ability', 1),
#  ('realm', 1)]

# %%
for token in result:
    print(token.text, token.pos_)
# Out:
# i PRON
# took VERB
# an DET
# african ADJ
# arts NOUN
# class NOUN
# with ADP
# poynor NOUN
# and CCONJ
# he PRON
# used VERB
# this DET
# book NOUN
# and CCONJ
# the DET
# slide NOUN
# images NOUN
# . PUNCT
# this DET
# was AUX
# a DET
# wonderful ADJ
# tool NOUN
# . PUNCT
# i PRON
# usually ADV
# hate VERB
# reading VERB
# art NOUN
# books NOUN
# but CCONJ
# this DET
# one NUM
# read VERB
# like ADP
# a DET
# recreational ADJ
# book NOUN
# . PUNCT
# great ADJ
# illustrations NOUN
# ! PUNCT
# if SCONJ
# u PROPN
# would AUX
# like VERB
# to PART
# learn VERB
# more ADJ
# about ADP
# the DET
# culture NOUN
# this DET
# is VERB
# definately ADV
# the DET
# book NOUN
# to PART
# get VERB
#
#  SPACE
